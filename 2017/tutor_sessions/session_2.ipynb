# %% [markdown]
# ## Informatik 1 - Biomedical Engineering
# ## Tutor Session 2 -  Branching

# %% [markdown]
# ## Overview
# <ul>
# <li>The if-Statment</li>
# <li>For Loop</li>
# <li>While Loop</li>
# <li>Examples</li>
#
# </ul>

# %% [markdown]
# ## The if-Statement
#
# If expression_1 is true, then instruction 1 should happen. If expression_2 is true, instruction 2 should happen. If both are not true, the else instruction will be executed.
#
# <li>Examples:</li>

# %%
if expression_1:
    #instruction 1
elif expression_2: #optional
    #instruction 2
else: #optional
    #else instruction

# %%
weather = input("How is the weather today (rainy/sunny): ")

if weather == "rainy":
    print("clean your room!")
elif weather == "sunny":
    print("you can go swimming :-)")
else:
    print("pff. don\’t have a recommendation.")
print("anyhow, watch a movie at night.")

# %% [markdown]
# ## For Loop
# <center>
# <img src="data:image/png;base64,..." alt="" />
# </center>

# %%
for item in sequence:
    statement(s)

# %%
#summarize even numbers
res = 0
for number in range(11):
    if number % 2 == 0:
        res += number
print(res)

# %% [markdown]
# Using range to iterate:

# %%
for i in range(0,9):
    print(i)

# %%
for i in range(9):
    print(i)

# %%
for i in range(5,9):
    print(i)

# %% [markdown]
# ## While Loop
# <center>
# <img src="data:image/png;base64,..." alt="" />
# </center>

# %%
while condition:
    #do_something

# %%
secure_pwd = "123"
user_inp = ""
attempts = 0

while user_inp != secure_pwd:
    user_inp = input("Enter pwd: ")
    attempts += 1
print("Authenticated after ", attempts," attempts")

# %% [markdown]
# # Example Program
# Calculating π using Leibniz’s formula.
# <center>
# <img src="data:image/png;base64,..." alt="" />
# </center>

# %%
#possible solution
ITERATIONS = 1000
subtotal = 0.0
for n in range(ITERATIONS):
    subtotal += (-1)**n / (2*n + 1)
pi = subtotal * 4
print("Pi is appr.:", pi)

# %% [markdown]
# Now try and print out the series:
# Write a program that prints the
# first six elements of the Leibniz
# series to the console. (See picture)
# <center>
# <img src="data:image/png;base64,..." alt="" />
# </center>
# Hint: Use a While Loop (or For
# Loop) which runs from 1 to 11

# %%
#possible solution:
last_denominator = 11
operator = "-"
act = 1
while act <= last_denominator:
    print(1, "/", act)
    print(" ", operator)
    act += 2
    if operator == "-":
        operator = "+"
    else:
        operator = "-"
print(" ...\n= pi / 4")
